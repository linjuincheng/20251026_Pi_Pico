# %%
print ("Hello! Python")
score=78 + 95 + 83 + 69 + 70
average = score / 5
print("學生總分為",score)
print("學生平均為",average)
# Out:
# Hello! Python
# 學生總分為 395
# 學生平均為 79.0

# %%
a = 10
b = 3

print(a + b)   # 13 (加法)
print(a - b)   # 7 (减法)
print(a * b)   # 30 (乘法)
print(a / b)   # 3.3333333333333335 (除法，结果是浮点数)
print(a // b)  # 3 (整除)
print(a % b)   # 1 (余数：10除以3余1)
print(a ** b)  # 1000 (10的3次方)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
n1=5+10
n2=20-15
n3=n1*n2
n4=n2/n1
n5=n2%n1
n6=n2**n1
print(n1,n2,n3,n4,n5,n6)
# Out:
# 15 5 75 0.3333333333333333 5 30517578125

# %%
print(a)
# Out:
# 10

# %%
print(10)
# Out:
# 10

# %%
a
b
# Out:
# 3

# %%
a
# Out:
# 10

# %%
# Python 基本資料型態示範

# 整數 (int)
age = 25
print("age =", age)
print("age 的資料型態是：", type(age))
print()

# 浮點數 (float)
height = 172.5
print("height =", height)
print("height 的資料型態是：", type(height))
print()

# 字串 (str)
name = "Juin-Cheng Lin"
print("name =", name)
print("name 的資料型態是：", type(name))
print()

# 布林值 (bool)
is_student = True
print("is_student =", is_student)
print("is_student 的資料型態是：", type(is_student))
print()

# 額外示範：布林值可用於條件判斷
if is_student:
    print(f"{name} is a student.")
else:
    print(f"{name} is not a student.")
# Out:
# age = 25
# age 的資料型態是： <class 'int'>
#
# height = 172.5
# height 的資料型態是： <class 'float'>
#
# name = Juin-Cheng Lin
# name 的資料型態是： <class 'str'>
#
# is_student = True
# is_student 的資料型態是： <class 'bool'>
#
# Juin-Cheng Lin is a student.

# %%
print(5+5.0)
# Out:
# 10.0

# %%
print(5+"5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(5+"5")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(5+5)
print(5+5.0)
print("5"+"5")
print('='*20)
# Out:
# 10
# 10.0
# 55
# ...

# %%
apple=5
orange=10

print('apple有5個,orange有10個')
print('apple有'+str(apple)+"個,orange有"+str(orange)+"個")
print(f"apple有{apple}個,orange有{orange}個") #字串插補
# Out:
# apple有5個,orange有10個
# apple有5個,orange有10個
# apple有5個,orange有10個
